# %%
import math
import time
import copy
import sys
import numpy as np
from sympy import numer
import csv


def main():
    print("Welcome to Crystal Feng's Evaluation Program.\n")
    dataset = int(input("Which data set would you like to use?\n"
                            "1. Small\n"
                            "2. Large\n"))
    
    if(dataset == 1):
        file = open('small-test-dataset.txt', 'r')
    elif(dataset == 2):
        file = open('Large-test-dataset.txt', 'r')

    searchAlgo = int(input('\nType the number of the algorithm you want to run\n'
                          '1. Forward Search\n'
                          '2. Backward Search\n'
                          '3. Bertie\'s Search Algorithm\n'))
    
    if searchAlgo == 1:
        forward(file)
    elif searchAlgo == 2:
        backward(file)

    

def matrix(file):
    data = []

    #source on how to convert txt data into matrix
    #https://stackoverflow.com/questions/48833873/turn-txt-file-into-matrix-of-ints-in-python
    for row in file:
        data.append([float(x) for x in row.split()])

    data = normalize(data)

    return data

def forward(file):
    fset = []
    realbest = 0
    print("Beginning Search\n")

    data = matrix(file)

    
    for i in range(1,len(data[0])):
        # print("on the " + str(i) + "th level of the search tree\n")
        best = 0
        curr = []
        for j in range(1,len(data[0])):
            
            if not j in fset:
                curr = [j]
                curr.extend(fset)
                    
                # print("++Consider adding the " + str(j) + " feature\n")
                accuracy = calcaccuracy(data, curr)
                
                print("Using features(s) " + str(curr) + " accuracy is " + str(accuracy) + "%\n")
                
                if accuracy > best:
                    best = accuracy
                    bestset = curr
                    
        if(best < realbest):
            print("\n(Warning, Accuracy has decreased!!)\n")
            print("Finished search!! The best feature sebset is "+ str(fset) + " which has an accuracy of " + str(realbest) + "%\n")
            break;
        fset = bestset
        realbest = best
        print("\nFeature set " + str(bestset) + " was best, accuracy is " + str(best) + "%\n\n")
        
def backward(file):
    fset=[]

    data = matrix(file)
    
    for i in range(1,len(data[0])):
        fset.append(i)
    
    accuracy = calcaccuracy(data, None)
    realbest = accuracy
    
    print("Using all features(s) " + str(fset) + " accuracy is " + str(accuracy) + "%\n")
        
    print("Beginning Search\n")

    for i in range(1,len(data[0])):
        best = 0
        curr = []
        for j in range(1,len(data[0])):
            if j in fset:
                curr = copy.deepcopy(fset)
            
                # print(str(curr) + "\n" + str(j) + "\n")
            
                curr.remove(j)
                # print(str(curr) + "\n" )
                accuracy = calcaccuracy(data, curr)
                
                print("Using features(s) " + str(curr) + " accuracy is " + str(accuracy) + "%\n")
            
                if accuracy > best:
                    best = accuracy
                    bestset = curr
                    
        if(best < realbest):
            print("\n(Warning, Accuracy has decreased!!)\n")
            print("Finished search!! The best feature sebset is "+ str(fset) + " which has an accuracy of " + str(realbest) + "%\n")
            break;
            
        fset = bestset
        realbest = best
        print("\nFeature set " + str(bestset) + " was best, accuracy is " + str(best) + "%\n\n")              
        
def calcaccuracy(matrix, current_set):
    # start_time = time.time()
    #open file
    number_correctly_classified = 0
    
    data = copy.deepcopy(matrix)
    
    for i in range(len(data)):
        #source on how to 0 out columns
        #https://stackoverflow.com/questions/36338927/how-to-zero-specific-column-of-2d-array
        if(current_set):
            for j in range(len(data[i])):
                if not j in current_set and j != 0:
                    data[i][j] = 0 
        
    for i in range(len(data)):

        object_to_clasify = []
        for j in range(len(data[i])):
            if(j != 0):
                object_to_clasify.append(data[i][j])

        label_object_to_classify = data[i][0]
        
        # print("Looping over i, at the " + str(i+1) + " location\n")
        # print("The " + str(i+1) + "th object is in class " + str(label) + "\n")
        
        nearest_neighbor_distance = float('inf')
        nearest_neighbor_location = float('inf')
        nearest_neighbor_label = None
        for j in range(len(data)):
            
            if i != j :
                # print("Ask if " + str(i+1) + " is nearest neighbor with " + str(j+1))
                compare = []
                for k in range(len(data[i])):
                    if(k != 0):
                        compare.append(data[j][k])
                
                distance = euclidean(object_to_clasify, compare)
                
                if distance < nearest_neighbor_distance:
                    # print("euclidean distance " + str(distance))
                    nearest_neighbor_distance = distance
                    nearest_neighbor_location = j
                    nearest_neighbor_label = data[nearest_neighbor_location][0]

        # print("object " + str(i+1) +"'s label is " + str(label_object_to_classify) +"\nits nearest neighbors is object " + str(nearest_neighbor_location+1)+ " with label " + str(nearest_neighbor_label))
        # print("Time to compute = " + str(time.time() - start_time) + " seconds\n\n")
        if label_object_to_classify == nearest_neighbor_label:
            number_correctly_classified += 1
    
    accuracy = number_correctly_classified/len(data)
    # print("\nAccuracy is " + str(accuracy*100) + "%")
    return accuracy*100

def euclidean(x, y):
    sum = 0
    # print(x)
    # print(y)
    for i in range(len(x)):
        dif = x[i] -y[i]
        square = pow(dif,2)
        sum += square
    dist = math.sqrt(sum)
    return dist

def normalize(data):
    for i in range(len(data[0])):
        if i > 0:
            min = sys.maxsize
            max = -sys.maxsize -1

            for j in range(len(data)):
                if data[j][i] < min:
                    min = data[j][i]
                if data[j][i] > max:
                    max = data[j][i]
        
            denominator = max - min

            for k in range(len(data)):
                numerator = data[k][i] - min
                data[k][i] = numerator/denominator

    return data

def printnorm(file):
    data1 = []

    #source on how to convert txt data into matrix
    #https://stackoverflow.com/questions/48833873/turn-txt-file-into-matrix-of-ints-in-python
    for row in file:
        data1.append([float(x) for x in row.split()])

    data = normalize(data1)

    for i in range(len(data[0])):
        if i > 0:
            min = sys.maxsize
            max = -sys.maxsize -1

            for j in range(len(data)):
                if data[j][i] < min:
                    min = data[j][i]
                if data[j][i] > max:
                    max = data[j][i]
        
            print("for col " + str(i) + " the min is " +str(min) + " and the max is" + str(max) + "\n")


    with open("output.csv", "w") as f:
        writer = csv.writer(f)
        writer.writerows(data)

if __name__ == '__main__':
    main()
# Out:
# Welcome to Crystal Feng's Evaluation Program.
#
# Beginning Search
#
# Using features(s) [1] accuracy is 73.8%
#
# Using features(s) [2] accuracy is 71.0%
#
# Using features(s) [3] accuracy is 67.30000000000001%
#
# Using features(s) [4] accuracy is 67.80000000000001%
#
# Using features(s) [5] accuracy is 69.19999999999999%
#
# Using features(s) [6] accuracy is 69.5%
#
# Using features(s) [7] accuracy is 70.6%
#
# Using features(s) [8] accuracy is 71.2%
#
# Using features(s) [9] accuracy is 68.0%
#
# Using features(s) [10] accuracy is 69.1%
#
# Using features(s) [11] accuracy is 70.5%
#
# Using features(s) [12] accuracy is 68.0%
#
# Using features(s) [13] accuracy is 65.8%
#
# Using features(s) [14] accuracy is 70.89999999999999%
#
# Using features(s) [15] accuracy is 69.5%
#
# Using features(s) [16] accuracy is 67.5%
#
# Using features(s) [17] accuracy is 67.30000000000001%
#
# Using features(s) [18] accuracy is 70.39999999999999%
#
# Using features(s) [19] accuracy is 69.6%
#
# Using features(s) [20] accuracy is 67.7%
#
# Using features(s) [21] accuracy is 68.30000000000001%
#
# Using features(s) [22] accuracy is 68.5%
#
# Using features(s) [23] accuracy is 70.19999999999999%
#
# Using features(s) [24] accuracy is 67.2%
#
# Using features(s) [25] accuracy is 69.3%
#
# Using features(s) [26] accuracy is 67.7%
#
# Using features(s) [27] accuracy is 84.7%
#
# Using features(s) [28] accuracy is 66.4%
#
# Using features(s) [29] accuracy is 69.89999999999999%
#
# Using features(s) [30] accuracy is 70.89999999999999%
#
# Using features(s) [31] accuracy is 69.89999999999999%
#
# Using features(s) [32] accuracy is 69.5%
#
# Using features(s) [33] accuracy is 70.1%
#
# Using features(s) [34] accuracy is 68.2%
#
# Using features(s) [35] accuracy is 69.89999999999999%
#
# Using features(s) [36] accuracy is 69.8%
#
# Using features(s) [37] accuracy is 70.5%
#
# Using features(s) [38] accuracy is 70.39999999999999%
#
# Using features(s) [39] accuracy is 71.0%
#
# Using features(s) [40] accuracy is 70.3%
#
#
# Feature set [27] was best, accuracy is 84.7%
#
#
# Using features(s) [1, 27] accuracy is 95.5%
#
# Using features(s) [2, 27] accuracy is 84.3%
#
# Using features(s) [3, 27] accuracy is 82.5%
#
# Using features(s) [4, 27] accuracy is 82.8%
#
# Using features(s) [5, 27] accuracy is 81.6%
#
# Using features(s) [6, 27] accuracy is 84.3%
#
# Using features(s) [7, 27] accuracy is 82.3%
#
# Using features(s) [8, 27] accuracy is 84.5%
#
# Using features(s) [9, 27] accuracy is 84.2%
#
# Using features(s) [10, 27] accuracy is 82.3%
#
# Using features(s) [11, 27] accuracy is 82.5%
#
# Using features(s) [12, 27] accuracy is 82.89999999999999%
#
# Using features(s) [13, 27] accuracy is 82.1%
#
# Using features(s) [14, 27] accuracy is 83.0%
#
# Using features(s) [15, 27] accuracy is 84.7%
#
# Using features(s) [16, 27] accuracy is 83.39999999999999%
#
# Using features(s) [17, 27] accuracy is 83.7%
#
# Using features(s) [18, 27] accuracy is 83.2%
#
# Using features(s) [19, 27] accuracy is 83.0%
#
# Using features(s) [20, 27] accuracy is 82.39999999999999%
#
# Using features(s) [21, 27] accuracy is 82.89999999999999%
#
# Using features(s) [22, 27] accuracy is 84.0%
#
# Using features(s) [23, 27] accuracy is 84.1%
#
# Using features(s) [24, 27] accuracy is 81.3%
#
# Using features(s) [25, 27] accuracy is 81.5%
#
# Using features(s) [26, 27] accuracy is 83.3%
#
# Using features(s) [28, 27] accuracy is 82.0%
#
# Using features(s) [29, 27] accuracy is 83.2%
#
# Using features(s) [30, 27] accuracy is 82.19999999999999%
#
# Using features(s) [31, 27] accuracy is 82.1%
#
# Using features(s) [32, 27] accuracy is 82.39999999999999%
#
# Using features(s) [33, 27] accuracy is 82.19999999999999%
#
# Using features(s) [34, 27] accuracy is 81.8%
#
# Using features(s) [35, 27] accuracy is 81.2%
#
# Using features(s) [36, 27] accuracy is 82.19999999999999%
#
# Using features(s) [37, 27] accuracy is 84.7%
#
# Using features(s) [38, 27] accuracy is 82.5%
#
# Using features(s) [39, 27] accuracy is 85.0%
#
# Using features(s) [40, 27] accuracy is 82.89999999999999%
#
#
# Feature set [1, 27] was best, accuracy is 95.5%
#
#
# Using features(s) [2, 1, 27] accuracy is 93.89999999999999%
#
# Using features(s) [3, 1, 27] accuracy is 93.0%
#
# Using features(s) [4, 1, 27] accuracy is 93.30000000000001%
#
# Using features(s) [5, 1, 27] accuracy is 91.7%
#
# Using features(s) [6, 1, 27] accuracy is 91.8%
#
# Using features(s) [7, 1, 27] accuracy is 92.80000000000001%
#
# Using features(s) [8, 1, 27] accuracy is 94.0%
#
# Using features(s) [9, 1, 27] accuracy is 92.9%
#
# Using features(s) [10, 1, 27] accuracy is 92.10000000000001%
#
# Using features(s) [11, 1, 27] accuracy is 91.9%
#
# Using features(s) [12, 1, 27] accuracy is 92.5%
#
# Using features(s) [13, 1, 27] accuracy is 92.30000000000001%
#
# Using features(s) [14, 1, 27] accuracy is 93.7%
#
# Using features(s) [15, 1, 27] accuracy is 94.69999999999999%
#
# Using features(s) [16, 1, 27] accuracy is 92.80000000000001%
#
# Using features(s) [17, 1, 27] accuracy is 91.5%
#
# Using features(s) [18, 1, 27] accuracy is 93.10000000000001%
#
# Using features(s) [19, 1, 27] accuracy is 92.7%
#
# Using features(s) [20, 1, 27] accuracy is 93.2%
#
# Using features(s) [21, 1, 27] accuracy is 93.0%
#
# Using features(s) [22, 1, 27] accuracy is 93.2%
#
# Using features(s) [23, 1, 27] accuracy is 93.30000000000001%
#
# Using features(s) [24, 1, 27] accuracy is 92.2%
#
# Using features(s) [25, 1, 27] accuracy is 92.9%
#
# Using features(s) [26, 1, 27] accuracy is 93.10000000000001%
#
# Using features(s) [28, 1, 27] accuracy is 92.80000000000001%
#
# Using features(s) [29, 1, 27] accuracy is 92.30000000000001%
#
# Using features(s) [30, 1, 27] accuracy is 92.80000000000001%
#
# Using features(s) [31, 1, 27] accuracy is 92.80000000000001%
#
# Using features(s) [32, 1, 27] accuracy is 92.10000000000001%
#
# Using features(s) [33, 1, 27] accuracy is 92.0%
#
# Using features(s) [34, 1, 27] accuracy is 91.8%
#
# Using features(s) [35, 1, 27] accuracy is 91.4%
#
# Using features(s) [36, 1, 27] accuracy is 92.80000000000001%
#
# Using features(s) [37, 1, 27] accuracy is 94.6%
#
# Using features(s) [38, 1, 27] accuracy is 93.5%
#
# Using features(s) [39, 1, 27] accuracy is 93.89999999999999%
#
# Using features(s) [40, 1, 27] accuracy is 92.9%
#
#
# (Warning, Accuracy has decreased!!)
#
# Finished search!! The best feature sebset is [1, 27] which has an accuracy of 95.5%
