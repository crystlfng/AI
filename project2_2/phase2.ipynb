# %%
import math
import time


def main():
    print("Welcome to Crystal Feng's Evaluation Program.\n")
    dataset = int(input("Which data set would you like to use?\n"
                            "1. Small\n"
                            "2. Large\n"))
    
    if(dataset == 1):
        file = open('small-test-dataset.txt', 'r')
    elif(dataset == 2):
        file = open('Large-test-dataset.txt', 'r')

    x = input("\nEnter the features you want to use seperated by spaces\n")
        
    features = x.split(' ')

    for i in range(len(features)):
        features[i]= int(features[i])

    # print(features)


    accuracy(file, features)

def accuracy(file, current_set):
    start_time = time.time()
    #open file
    number_correctly_classified = 0
    
    current_set.append(0)
    
    data = []

    #source on how to convert txt data into matrix
    #https://stackoverflow.com/questions/48833873/turn-txt-file-into-matrix-of-ints-in-python
    for row in file:
        data.append([float(x) for x in row.split()])

    
    
    for i in range(len(data)):
        #source on how to 0 out columns
        #https://stackoverflow.com/questions/36338927/how-to-zero-specific-column-of-2d-array
        for j in range(len(data[i])):
            if not j in current_set:
                data[i][j] = 0 
        
    for i in range(len(data)):

        object_to_clasify = []
        for j in range(len(data[i])):
            if(j != 0):
                object_to_clasify.append(data[i][j])

        label_object_to_classify = data[i][0]
        
        # print("Looping over i, at the " + str(i+1) + " location\n")
        # print("The " + str(i+1) + "th object is in class " + str(label) + "\n")
        
        nearest_neighbor_distance = float('inf')
        nearest_neighbor_location = float('inf')
        nearest_neighbor_label = None
        for j in range(len(data)):
            
            if i != j :
                # print("Ask if " + str(i+1) + " is nearest neighbor with " + str(j+1))
                compare = []
                for k in range(len(data[i])):
                    if(k != 0):
                        compare.append(data[j][k])
                
                distance = euclidean(object_to_clasify, compare)
                
                if distance < nearest_neighbor_distance:
                    # print("euclidean distance " + str(distance))
                    nearest_neighbor_distance = distance
                    nearest_neighbor_location = j
                    nearest_neighbor_label = data[nearest_neighbor_location][0]

        print("object " + str(i+1) +"'s label is " + str(label_object_to_classify) +"\nits nearest neighbors is object " + str(nearest_neighbor_location+1)+ " with label " + str(nearest_neighbor_label))
        print("Time to compute = " + str(time.time() - start_time) + " seconds\n\n")
        if label_object_to_classify == nearest_neighbor_label:
            number_correctly_classified += 1
    
    accuracy = number_correctly_classified/len(data)
    print("\nAccuracy is " + str(accuracy) + "%")

def euclidean(x, y):
    sum = 0
    # print(x)
    # print(y)
    for i in range(len(x)):
        dif = x[i] -y[i]
        square = pow(dif,2)
        sum += square
    dist = math.sqrt(sum)
    return dist

   



if __name__ == '__main__':
    main()
# Out:
# Welcome to Crystal Feng's Evaluation Program.
#
# object 1's label is 2.0
# its nearest neighbors is object 27 with label 2.0
# Time to compute = 0.0009996891021728516 seconds
#
#
# object 2's label is 2.0
# its nearest neighbors is object 32 with label 2.0
# Time to compute = 0.0015003681182861328 seconds
#
#
# object 3's label is 2.0
# its nearest neighbors is object 92 with label 2.0
# Time to compute = 0.0020008087158203125 seconds
#
#
# object 4's label is 2.0
# its nearest neighbors is object 67 with label 1.0
# Time to compute = 0.0025010108947753906 seconds
#
#
# object 5's label is 2.0
# its nearest neighbors is object 63 with label 2.0
# Time to compute = 0.003501415252685547 seconds
#
#
# object 6's label is 2.0
# its nearest neighbors is object 61 with label 2.0
# Time to compute = 0.004002094268798828 seconds
#
#
# object 7's label is 2.0
# its nearest neighbors is object 97 with label 2.0
# Time to compute = 0.004503011703491211 seconds
#
#
# object 8's label is 2.0
# its nearest neighbors is object 48 with label 2.0
# Time to compute = 0.0050029754638671875 seconds
#
#
# object 9's label is 2.0
# its nearest neighbors is object 43 with label 2.0
# Time to compute = 0.005502939224243164 seconds
#
#
# object 10's label is 1.0
# its nearest neighbors is object 95 with label 1.0
# Time to compute = 0.0060045719146728516 seconds
#
#
# object 11's label is 2.0
# its nearest neighbors is object 50 with label 2.0
# Time to compute = 0.00650477409362793 seconds
#
#
# object 12's label is 2.0
# its nearest neighbors is object 60 with label 2.0
# Time to compute = 0.007005214691162109 seconds
#
#
# object 13's label is 1.0
# its nearest neighbors is object 82 with label 1.0
# Time to compute = 0.0075054168701171875 seconds
#
#
# object 14's label is 2.0
# its nearest neighbors is object 65 with label 2.0
# Time to compute = 0.008006095886230469 seconds
#
#
# object 15's label is 2.0
# its nearest neighbors is object 34 with label 2.0
# Time to compute = 0.008506059646606445 seconds
#
#
# object 16's label is 1.0
# its nearest neighbors is object 49 with label 1.0
# Time to compute = 0.009006738662719727 seconds
#
#
# object 17's label is 2.0
# its nearest neighbors is object 39 with label 2.0
# Time to compute = 0.009506940841674805 seconds
#
#
# object 18's label is 2.0
# its nearest neighbors is object 74 with label 2.0
# Time to compute = 0.010007619857788086 seconds
#
#
# object 19's label is 2.0
# its nearest neighbors is object 69 with label 2.0
# Time to compute = 0.010508060455322266 seconds
#
#
# object 20's label is 2.0
# its nearest neighbors is object 62 with label 2.0
# Time to compute = 0.011008024215698242 seconds
#
#
# object 21's label is 1.0
# its nearest neighbors is object 31 with label 1.0
# Time to compute = 0.011508703231811523 seconds
#
#
# object 22's label is 2.0
# its nearest neighbors is object 63 with label 2.0
# Time to compute = 0.012009382247924805 seconds
#
#
# object 23's label is 1.0
# its nearest neighbors is object 26 with label 1.0
# Time to compute = 0.012509584426879883 seconds
#
#
# object 24's label is 2.0
# its nearest neighbors is object 58 with label 2.0
# Time to compute = 0.01351022720336914 seconds
#
#
# object 25's label is 2.0
# its nearest neighbors is object 53 with label 1.0
# Time to compute = 0.014011383056640625 seconds
#
#
# object 26's label is 1.0
# its nearest neighbors is object 66 with label 1.0
# Time to compute = 0.014511346817016602 seconds
#
#
# object 27's label is 2.0
# its nearest neighbors is object 68 with label 2.0
# Time to compute = 0.015011787414550781 seconds
#
#
# object 28's label is 1.0
# its nearest neighbors is object 31 with label 1.0
# Time to compute = 0.015512228012084961 seconds
#
#
# object 29's label is 2.0
# its nearest neighbors is object 50 with label 2.0
# Time to compute = 0.016013145446777344 seconds
#
#
# object 30's label is 2.0
# its nearest neighbors is object 17 with label 2.0
# Time to compute = 0.01651310920715332 seconds
#
#
# object 31's label is 1.0
# its nearest neighbors is object 28 with label 1.0
# Time to compute = 0.0170137882232666 seconds
#
#
# object 32's label is 2.0
# its nearest neighbors is object 2 with label 2.0
# Time to compute = 0.017513751983642578 seconds
#
#
# object 33's label is 2.0
# its nearest neighbors is object 83 with label 2.0
# Time to compute = 0.018014192581176758 seconds
#
#
# object 34's label is 2.0
# its nearest neighbors is object 15 with label 2.0
# Time to compute = 0.018514633178710938 seconds
#
#
# object 35's label is 1.0
# its nearest neighbors is object 52 with label 1.0
# Time to compute = 0.019015073776245117 seconds
#
#
# object 36's label is 2.0
# its nearest neighbors is object 3 with label 2.0
# Time to compute = 0.019515514373779297 seconds
#
#
# object 37's label is 2.0
# its nearest neighbors is object 35 with label 1.0
# Time to compute = 0.020015954971313477 seconds
#
#
# object 38's label is 2.0
# its nearest neighbors is object 73 with label 2.0
# Time to compute = 0.020516395568847656 seconds
#
#
# object 39's label is 2.0
# its nearest neighbors is object 90 with label 2.0
# Time to compute = 0.021016836166381836 seconds
#
#
# object 40's label is 2.0
# its nearest neighbors is object 42 with label 2.0
# Time to compute = 0.021517038345336914 seconds
#
#
# object 41's label is 2.0
# its nearest neighbors is object 87 with label 2.0
# Time to compute = 0.022017478942871094 seconds
#
#
# object 42's label is 2.0
# its nearest neighbors is object 40 with label 2.0
# Time to compute = 0.022518157958984375 seconds
#
#
# object 43's label is 2.0
# its nearest neighbors is object 51 with label 2.0
# Time to compute = 0.023018598556518555 seconds
#
#
# object 44's label is 2.0
# its nearest neighbors is object 91 with label 2.0
# Time to compute = 0.023518800735473633 seconds
#
#
# object 45's label is 2.0
# its nearest neighbors is object 94 with label 2.0
# Time to compute = 0.024019479751586914 seconds
#
#
# object 46's label is 2.0
# its nearest neighbors is object 61 with label 2.0
# Time to compute = 0.024519920349121094 seconds
#
#
# object 47's label is 1.0
# its nearest neighbors is object 88 with label 1.0
# Time to compute = 0.025021076202392578 seconds
#
#
# object 48's label is 2.0
# its nearest neighbors is object 99 with label 2.0
# Time to compute = 0.025520801544189453 seconds
#
#
# object 49's label is 1.0
# its nearest neighbors is object 66 with label 1.0
# Time to compute = 0.026021957397460938 seconds
#
#
# object 50's label is 2.0
# its nearest neighbors is object 71 with label 2.0
# Time to compute = 0.026521682739257812 seconds
#
#
# object 51's label is 2.0
# its nearest neighbors is object 43 with label 2.0
# Time to compute = 0.027022123336791992 seconds
#
#
# object 52's label is 1.0
# its nearest neighbors is object 70 with label 1.0
# Time to compute = 0.02752208709716797 seconds
#
#
# object 53's label is 1.0
# its nearest neighbors is object 47 with label 1.0
# Time to compute = 0.02802300453186035 seconds
#
#
# object 54's label is 1.0
# its nearest neighbors is object 95 with label 1.0
# Time to compute = 0.028523683547973633 seconds
#
#
# object 55's label is 2.0
# its nearest neighbors is object 22 with label 2.0
# Time to compute = 0.02902388572692871 seconds
#
#
# object 56's label is 2.0
# its nearest neighbors is object 98 with label 1.0
# Time to compute = 0.02952408790588379 seconds
#
#
# object 57's label is 2.0
# its nearest neighbors is object 16 with label 1.0
# Time to compute = 0.03002476692199707 seconds
#
#
# object 58's label is 2.0
# its nearest neighbors is object 24 with label 2.0
# Time to compute = 0.03052520751953125 seconds
#
#
# object 59's label is 2.0
# its nearest neighbors is object 80 with label 2.0
# Time to compute = 0.031025409698486328 seconds
#
#
# object 60's label is 2.0
# its nearest neighbors is object 55 with label 2.0
# Time to compute = 0.03152585029602051 seconds
#
#
# object 61's label is 2.0
# its nearest neighbors is object 46 with label 2.0
# Time to compute = 0.03202700614929199 seconds
#
#
# object 62's label is 2.0
# its nearest neighbors is object 100 with label 2.0
# Time to compute = 0.03252696990966797 seconds
#
#
# object 63's label is 2.0
# its nearest neighbors is object 22 with label 2.0
# Time to compute = 0.03302717208862305 seconds
#
#
# object 64's label is 2.0
# its nearest neighbors is object 92 with label 2.0
# Time to compute = 0.03352761268615723 seconds
#
#
# object 65's label is 2.0
# its nearest neighbors is object 14 with label 2.0
# Time to compute = 0.03402829170227051 seconds
#
#
# object 66's label is 1.0
# its nearest neighbors is object 26 with label 1.0
# Time to compute = 0.034528493881225586 seconds
#
#
# object 67's label is 1.0
# its nearest neighbors is object 35 with label 1.0
# Time to compute = 0.035028934478759766 seconds
#
#
# object 68's label is 2.0
# its nearest neighbors is object 27 with label 2.0
# Time to compute = 0.035529375076293945 seconds
#
#
# object 69's label is 2.0
# its nearest neighbors is object 19 with label 2.0
# Time to compute = 0.03603029251098633 seconds
#
#
# object 70's label is 1.0
# its nearest neighbors is object 52 with label 1.0
# Time to compute = 0.036530256271362305 seconds
#
#
# object 71's label is 2.0
# its nearest neighbors is object 50 with label 2.0
# Time to compute = 0.03703045845031738 seconds
#
#
# object 72's label is 2.0
# its nearest neighbors is object 55 with label 2.0
# Time to compute = 0.037531375885009766 seconds
#
#
# object 73's label is 2.0
# its nearest neighbors is object 88 with label 1.0
# Time to compute = 0.03803133964538574 seconds
#
#
# object 74's label is 2.0
# its nearest neighbors is object 100 with label 2.0
# Time to compute = 0.038532257080078125 seconds
#
#
# object 75's label is 2.0
# its nearest neighbors is object 9 with label 2.0
# Time to compute = 0.0390324592590332 seconds
#
#
# object 76's label is 2.0
# its nearest neighbors is object 34 with label 2.0
# Time to compute = 0.03953266143798828 seconds
#
#
# object 77's label is 2.0
# its nearest neighbors is object 58 with label 2.0
# Time to compute = 0.04003334045410156 seconds
#
#
# object 78's label is 2.0
# its nearest neighbors is object 13 with label 1.0
# Time to compute = 0.04053354263305664 seconds
#
#
# object 79's label is 1.0
# its nearest neighbors is object 62 with label 2.0
# Time to compute = 0.04103422164916992 seconds
#
#
# object 80's label is 2.0
# its nearest neighbors is object 59 with label 2.0
# Time to compute = 0.0415346622467041 seconds
#
#
# object 81's label is 2.0
# its nearest neighbors is object 19 with label 2.0
# Time to compute = 0.042035579681396484 seconds
#
#
# object 82's label is 1.0
# its nearest neighbors is object 13 with label 1.0
# Time to compute = 0.04253554344177246 seconds
#
#
# object 83's label is 2.0
# its nearest neighbors is object 22 with label 2.0
# Time to compute = 0.04303574562072754 seconds
#
#
# object 84's label is 2.0
# its nearest neighbors is object 42 with label 2.0
# Time to compute = 0.04353594779968262 seconds
#
#
# object 85's label is 1.0
# its nearest neighbors is object 96 with label 2.0
# Time to compute = 0.0440363883972168 seconds
#
#
# object 86's label is 1.0
# its nearest neighbors is object 47 with label 1.0
# Time to compute = 0.04453706741333008 seconds
#
#
# object 87's label is 2.0
# its nearest neighbors is object 41 with label 2.0
# Time to compute = 0.04503750801086426 seconds
#
#
# object 88's label is 1.0
# its nearest neighbors is object 47 with label 1.0
# Time to compute = 0.04553818702697754 seconds
#
#
# object 89's label is 1.0
# its nearest neighbors is object 13 with label 1.0
# Time to compute = 0.04603862762451172 seconds
#
#
# object 90's label is 2.0
# its nearest neighbors is object 39 with label 2.0
# Time to compute = 0.0465388298034668 seconds
#
#
# object 91's label is 2.0
# its nearest neighbors is object 44 with label 2.0
# Time to compute = 0.04703950881958008 seconds
#
#
# object 92's label is 2.0
# its nearest neighbors is object 64 with label 2.0
# Time to compute = 0.047539472579956055 seconds
#
#
# object 93's label is 2.0
# its nearest neighbors is object 81 with label 2.0
# Time to compute = 0.04804039001464844 seconds
#
#
# object 94's label is 2.0
# its nearest neighbors is object 3 with label 2.0
# Time to compute = 0.04853987693786621 seconds
#
#
# object 95's label is 1.0
# its nearest neighbors is object 54 with label 1.0
# Time to compute = 0.049040794372558594 seconds
#
#
# object 96's label is 2.0
# its nearest neighbors is object 85 with label 1.0
# Time to compute = 0.049541473388671875 seconds
#
#
# object 97's label is 2.0
# its nearest neighbors is object 7 with label 2.0
# Time to compute = 0.050041913986206055 seconds
#
#
# object 98's label is 1.0
# its nearest neighbors is object 56 with label 2.0
# Time to compute = 0.050542354583740234 seconds
#
#
# object 99's label is 2.0
# its nearest neighbors is object 48 with label 2.0
# Time to compute = 0.05104255676269531 seconds
#
#
# object 100's label is 2.0
# its nearest neighbors is object 62 with label 2.0
# Time to compute = 0.05154299736022949 seconds
#
#
#
# Accuracy is 0.89%
